# %% [markdown]
# ## Práctico 4: Eight Puzzle

# %%
from eight_puzzle import EightPuzzle

env = EightPuzzle()

# %%
print(env.action_space)
# Out:
# Discrete(4)

# %%
print(env.observation_space)
# Out:
# Box(0.0, 9.0, (9,), float32)

# %%
env.reset()
env.render()
# Out:
# 3|2|
# 4|5|8
# 6|7|1

# %%
for _ in range(10):
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    print(f"Observation: {observation}, Reward: {reward}, Done: {done}, Info: {info}")
    env.render()
# Out:
# Observation: [3 0 2 4 5 8 6 7 1], Reward: -16.0, Done: False, Info: {}
# 3| |2
# 4|5|8
# 6|7|1
# Action: R
#
# Observation: [3 2 0 4 5 8 6 7 1], Reward: -14.0, Done: False, Info: {}
# 3|2|
# 4|5|8
# 6|7|1
# Action: L
#
# Observation: [3 0 2 4 5 8 6 7 1], Reward: -16.0, Done: False, Info: {}
# 3| |2
# 4|5|8
# 6|7|1
# Action: R
#
# Observation: [3 0 2 4 5 8 6 7 1], Reward: -16.0, Done: False, Info: {}
# 3| |2
# 4|5|8
# 6|7|1
# Action: D
#
# Observation: [3 5 2 4 0 8 6 7 1], Reward: -16.0, Done: False, Info: {}
# 3|5|2
# 4| |8
# 6|7|1
# Action: U
#
# Observation: [3 0 2 4 5 8 6 7 1], Reward: -16.0, Done: False, Info: {}
# 3| |2
# 4|5|8
# 6|7|1
# Action: D
#
# Observation: [3 5 2 4 0 8 6 7 1], Reward: -16.0, Done: False, Info: {}
# 3|5|2
# 4| |8
# 6|7|1
# Action: U
#
# Observation: [3 5 2 0 4 8 6 7 1], Reward: -18.0, Done: False, Info: {}
# 3|5|2
#  |4|8
# 6|7|1
# Action: R
#
# Observation: [3 5 2 0 4 8 6 7 1], Reward: -18.0, Done: False, Info: {}
# 3|5|2
#  |4|8
# 6|7|1
# Action: R
#
# Observation: [0 5 2 3 4 8 6 7 1], Reward: -20.0, Done: False, Info: {}
#  |5|2
# 3|4|8
# 6|7|1
# Action: D
